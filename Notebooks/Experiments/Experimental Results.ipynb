# %% [markdown]
# # **Experimental Results**

# %% [markdown]
# ## **BM25 Retrieval with Top 100 Documents Reranked by Vanilla BERT**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **BM25 Retrieval with Top 100 Documents Reranked by PubMedBERT**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **BM25 Retrieval with Top 100 Documents Reranked by CoronaBERT**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **BM25 Retrieval with Top 24 Documents Reranked by CoronaBERT Classification Model**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **BM25 Retrieval with Queries Expanded using Vanilla BERT DeepCT**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **BM25 Retrieval with Queries Expanded using CoronaBERT DeepCT**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **BM25 Retrieval with 100 Highest Altmetric Predictions Selected**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
